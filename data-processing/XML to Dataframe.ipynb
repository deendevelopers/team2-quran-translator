# %%
import pandas as pd
import xml.etree.ElementTree as ET
from pathlib import Path

# %% [markdown]
# ## Parse the Arabic Text

# %%
xml_quran_fp = Path('../data/quran-uthmani.xml')

# %%
xml_quran_root = ET.parse(xml_quran_fp).getroot()

# %%
columns = ['Surah Name', 'Surah Number', 'Verse Number', 'Verse Text']

df = pd.DataFrame(columns=columns)

# %%
for sura_element in xml_quran_root:
    sura_num = int(sura_element.attrib.get('index'))
    sura_name = sura_element.attrib.get('name')
    for verse_element in sura_element:
        verse_num = int(verse_element.get('index'))
        verse_text = verse_element.get('text')
        df = df.append(pd.Series([sura_name, sura_num, verse_num, verse_text],
                                 index=columns), ignore_index=True)

# %%
df.head()
# Out:
#   Surah Name Surah Number Verse Number  \
# 0    الفاتحة            1            1
# 1    الفاتحة            1            2
# 2    الفاتحة            1            3
# 3    الفاتحة            1            4
# 4    الفاتحة            1            5
#
#                                  Verse Text
# 0    بِسْمِ ٱللَّهِ ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
# 1     ٱلْحَمْدُ لِلَّهِ رَبِّ ٱلْعَٰلَمِينَ
# 2                   ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
# 3                   مَٰلِكِ يَوْمِ ٱلدِّينِ
# 4  إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ

# %%
df = df.set_index(['Surah Number', 'Verse Number'])

# %%
df.head()
# Out:
#                           Surah Name                                Verse Text
# Surah Number Verse Number
# 1            1               الفاتحة    بِسْمِ ٱللَّهِ ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
#              2               الفاتحة     ٱلْحَمْدُ لِلَّهِ رَبِّ ٱلْعَٰلَمِينَ
#              3               الفاتحة                   ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
#              4               الفاتحة                   مَٰلِكِ يَوْمِ ٱلدِّينِ
#              5               الفاتحة  إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ

# %%
arabic_df = df.copy()

# %%
arabic_df.head()
# Out:
#                           Surah Name                                Verse Text
# Surah Number Verse Number
# 1            1               الفاتحة    بِسْمِ ٱللَّهِ ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
#              2               الفاتحة     ٱلْحَمْدُ لِلَّهِ رَبِّ ٱلْعَٰلَمِينَ
#              3               الفاتحة                   ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
#              4               الفاتحة                   مَٰلِكِ يَوْمِ ٱلدِّينِ
#              5               الفاتحة  إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ

# %% [markdown]
# ## Parse English translation

# %%
xml_trans_files = list(Path('../data/en_trans_xml_files').iterdir())

# %%
import numpy as np

# %%
for xml_en_file in xml_trans_files:
    trans_code = xml_en_file.name.strip('.xml').replace('.','_')
    print(trans_code)
    df[trans_code] = np.nan
    root = ET.parse(xml_en_file).getroot()
    for sura_element in root:
        sura_num = int(sura_element.attrib.get('index'))
        sura_name = sura_element.attrib.get('name')
        for verse_element in sura_element:
            verse_num = int(verse_element.get('index'))
            verse_text = verse_element.get('text')
            df[trans_code].loc[sura_num, verse_num] = verse_text
# Out:
# en_sahih
# en_sarwar
# en_shakir
# en_daryabadi
# en_ahmedraza
# en_ahmedali
# en_qaribullah
# en_yusufali
# en_wahiduddin
# en_maududi
# en_mubarakpuri
# en_qarai
# en_picktha
# en_itani
# en_arberry
# en_hilali
# en_transliteration

# %%
df.head()
# Out:
#                           Surah Name  \
# Surah Number Verse Number
# 1            1               الفاتحة
#              2               الفاتحة
#              3               الفاتحة
#              4               الفاتحة
#              5               الفاتحة
#
#                                                          Verse Text  \
# Surah Number Verse Number
# 1            1               بِسْمِ ٱللَّهِ ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
#              2                ٱلْحَمْدُ لِلَّهِ رَبِّ ٱلْعَٰلَمِينَ
#              3                              ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
#              4                              مَٰلِكِ يَوْمِ ٱلدِّينِ
#              5             إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ
#
#                                                                     en_sahih  \
# Surah Number Verse Number
# 1            1             In the name of Allah, the Entirely Merciful, t...
#              2             [All] praise is [due] to Allah, Lord of the wo...
#              3               The Entirely Merciful, the Especially Merciful,
#              4                           Sovereign of the Day of Recompense.
#              5                 It is You we worship and You we ask for help.
#
#                                                                    en_sarwar  \
# Surah Number Verse Number
# 1            1             In the Name of Allah, the Beneficent, the Merc...
#              2              All praise belongs to God, Lord of the Universe,
#              3                                  the Beneficent, the Merciful
#              4                             and Master of the Day of Judgment
#              5             (Lord), You alone We do worship and from You a...
#
#                                                                    en_shakir  \
# Surah Number Verse Number
# 1            1             In the name of Allah, the Beneficent, the Merc...
#              2             All praise is due to Allah, the Lord of the Wo...
#              3                                 The Beneficent, the Merciful.
#              4                                Master of the Day of Judgment.
#              5             Thee do we serve and Thee do we beseech for help.
#
#                                                                 en_daryabadi  \
# Surah Number Verse Number
# 1            1             In the name of Allah, the Compassionate, the M...
#              2             All praise unto Allah, the Lord of all the wor...
#              3                              The Compassionate, the Merciful.
#              4                             Sovereign of the Day of Requital.
#              5             Thee alone do we worship and of Thee alone do ...
#
#                                                                 en_ahmedraza  \
# Surah Number Verse Number
# 1            1             Allah - beginning with the name of - the Most ...
#              2             All praise is to Allah, the Lord Of The Creation.
#              3                          The Most Gracious, the Most Merciful
#              4                                Owner of the Day of Recompense
#              5             You alone we worship and from You alone we see...
#
#                                                                  en_ahmedali  \
# Surah Number Verse Number
# 1            1             In the name of Allah, most benevolent, ever-me...
#              2               ALL PRAISE BE to Allah, Lord of all the worlds,
#              3                               Most beneficent, ever-merciful,
#              4                                 King of the Day of Judgement.
#              5             You alone we worship, and to You alone turn fo...
#
#                                                                en_qaribullah  \
# Surah Number Verse Number
# 1            1             In the Name of Allah, the Merciful, the Most M...
#              2                       Praise be to Allah, Lord of the Worlds,
#              3                              the Merciful, the Most Merciful,
#              4                               Owner of the Day of Recompense.
#              5             You (alone) we worship; and You (alone) we rel...
#
#                                                                  en_yusufali  \
# Surah Number Verse Number
# 1            1             In the name of Allah, Most Gracious, Most Merc...
#              2             Praise be to Allah, the Cherisher and Sustaine...
#              3                                 Most Gracious, Most Merciful;
#              4                                Master of the Day of Judgment.
#              5                    Thee do we worship, and Thine aid we seek.
#
#                                                                en_wahiduddin  \
# Surah Number Verse Number
# 1            1             ﻿In the name of God, the Most Gracious, the Mo...
#              2             All praise is due to God, the Lord of the Univ...
#              3                                 the Beneficent, the Merciful;
#              4                                 Lord of the Day of Judgement.
#              5             You alone we worship, and to You alone we turn...
#
#                                                                   en_maududi  \
# Surah Number Verse Number
# 1            1             In the name of Allah, the Merciful, the Compas...
#              2             Praise be to Allah, the Lord of the entire uni...
#              3                               The Merciful, the Compassionate
#              4                          The Master of the Day of Recompense.
#              5             You alone do we worship, and You alone do we t...
#
#                                                               en_mubarakpuri  \
# Surah Number Verse Number
# 1            1             In the Name of Allah, the Most Gracious, the M...
#              2             Al-Hamd be to Allah, the Lord of all that exists.
#              3             Ar-Rahman (the Most Gracious), Ar-Rahim (the M...
#              4                           The Owner of the Day of Recompense.
#              5                      You we worship, and You we ask for help.
#
#                                                                     en_qarai  \
# Surah Number Verse Number
# 1            1             In the Name of Allah, the All-beneficent, the ...
#              2             All praise belongs to Allah, Lord of all the w...
#              3                         the All-beneficent, the All-merciful,
#              4                             Master of the Day of Retribution.
#              5             You [alone] do we worship, and to You [alone] ...
#
#                                                                   en_picktha  \
# Surah Number Verse Number
# 1            1             In the name of Allah, the Beneficent, the Merc...
#              2                       Praise be to Allah, Lord of the Worlds,
#              3                                 The Beneficent, the Merciful.
#              4                                Master of the Day of Judgment,
#              5             Thee (alone) we worship; Thee (alone) we ask f...
#
#                                                                     en_itani  \
# Surah Number Verse Number
# 1            1               In the name of God, the Gracious, the Merciful.
#              2                         Praise be to God, Lord of the Worlds.
#              3                         The Most Gracious, the Most Merciful.
#              4                                Master of the Day of Judgment.
#              5             It is You we worship, and upon You we call for...
#
#                                                                   en_arberry  \
# Surah Number Verse Number
# 1            1             In the Name of God, the Merciful, the Compassi...
#              2                 Praise belongs to God, the Lord of all Being,
#              3                      the All-merciful, the All-compassionate,
#              4                                the Master of the Day of Doom.
#              5             Thee only we serve; to Thee alone we pray for ...
#
#                                                                    en_hilali  \
# Surah Number Verse Number
# 1            1             In the Name of Allah, the Most Beneficent, the...
#              2             All the praises and thanks be to Allah, the Lo...
#              3                       The Most Beneficent, the Most Merciful.
#              4             The Only Owner (and the Only Ruling Judge) of ...
#              5             You (Alone) we worship, and you (Alone) we ask...
#
#                                                           en_transliteration
# Surah Number Verse Number
# 1            1             Bismi All<u>a</U>hi a<b>l</B>rra<u>h</U>m<u>a<...
#              2             Al<u>h</U>amdu lill<u>a</U>hi rabbi alAA<u>a</...
#              3             A<b>l</B>rra<u>h</U>m<u>a</U>ni a<b>l</B>rra<u...
#              4                    M<u>a</U>liki yawmi a<b>l</B>ddeen<b>i</b>
#              5             Iyy<u>a</U>ka naAAbudu waiyy<u>a</U>ka nastaAA...

# %%
df.to_json('../data/translation.json')

# %%
df.to_pickle('../data/df_translation.pckl')
